# %% [markdown]
# # My First Notebook
#
# Welcome to my first Jupyter notebook! This is an interactive computational environment where you can write and execute code, visualize data, and document your work.
#
# ## Getting Started
#
# Let's explore some basic Python functionality.

# %%
# Your first Python cell
print('Hello, World!')
print('Welcome to Jupyter Notebooks!')

# %% [markdown]
# ## Variables and Data Types

# %%
# Working with variables
name = 'Jupyter'
version = 1.0
is_active = True

print(f'Name: {name}')
print(f'Version: {version}')
print(f'Active: {is_active}')

# %% [markdown]
# ## Simple Calculations

# %%
# Basic math operations
a = 10
b = 5

print(f'{a} + {b} = {a + b}')
print(f'{a} - {b} = {a - b}')
print(f'{a} * {b} = {a * b}')
print(f'{a} / {b} = {a / b}')
